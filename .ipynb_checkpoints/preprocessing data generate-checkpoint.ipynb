# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('df_new_with_nan.csv')
df.head()
# Out:
#                       district       doc  pre_date  cur_date  days  pre_read  \
# 0  ناحيه 50 مراکز اداري دولتي   11292510    960418    970825    47      1564
# 1                ناحيه 8 گرگان  11705225    980921    961014    97     10395
# 2                ناحيه 5 گرگان  11147901    950426    980207   173     13502
# 3                ناحيه 4 گرگان  11157787    941010    990214   152      7385
# 4                ناحيه 6 گرگان  41119865    981125    960226    82     12472
#
#    cur_read  consumption     bill        obstcle       meter             Y  \
# 0     16155          412   633996            NaN  1396/02/19  4.079694e+06
# 1     12159          371   568685     قرائت نشده  1395/06/20           NaN
# 2     13985          410   108353  از کار افتاده  1390/12/24           NaN
# 3      3188          433  1219749     قرائت نشده  1391/02/12           NaN
# 4     12692          486   136407     قرائت نشده  1397/11/25           NaN
#
#                X        ID  flats land_use  capacity  diameter
# 0  270177.868594  46620700     42   مسكوني       100      0.75
# 1            NaN  43055800     17   مسكوني        70      0.75
# 2  272725.693345  36070600     13   مسكوني        66      0.75
# 3            NaN  42761200      9   مسكوني        60      0.75
# 4  271984.104536  12030900     42   مسكوني        17      0.75

# %%
df['district'] = pd.factorize(df['district'])[0]
df['district'] = df['district'].astype('category')

# %%
df['land_use'] = pd.factorize(df['land_use'])[0]
df['land_use'] = df['land_use'].astype('category')

# %%
df.head()
# Out:
#   district       doc  pre_date  cur_date  days  pre_read  cur_read  \
# 0        0  11292510    960418    970825    47      1564     16155
# 1        1  11705225    980921    961014    97     10395     12159
# 2        2  11147901    950426    980207   173     13502     13985
# 3        3  11157787    941010    990214   152      7385      3188
# 4        4  41119865    981125    960226    82     12472     12692
#
#    consumption     bill        obstcle       meter             Y  \
# 0          412   633996            NaN  1396/02/19  4.079694e+06
# 1          371   568685     قرائت نشده  1395/06/20           NaN
# 2          410   108353  از کار افتاده  1390/12/24           NaN
# 3          433  1219749     قرائت نشده  1391/02/12           NaN
# 4          486   136407     قرائت نشده  1397/11/25           NaN
#
#                X        ID  flats land_use  capacity  diameter
# 0  270177.868594  46620700     42        0       100      0.75
# 1            NaN  43055800     17        0        70      0.75
# 2  272725.693345  36070600     13        0        66      0.75
# 3            NaN  42761200      9        0        60      0.75
# 4  271984.104536  12030900     42        0        17      0.75

# %%
df.meter = df.meter.str.replace('/','')
df.meter = df.meter.astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   district     10000 non-null  category
#  1   doc          10000 non-null  int64
#  2   pre_date     10000 non-null  int64
#  3   cur_date     10000 non-null  int64
#  4   days         10000 non-null  int64
#  5   pre_read     10000 non-null  int64
#  6   cur_read     10000 non-null  int64
#  7   consumption  10000 non-null  int64
#  8   bill         10000 non-null  int64
#  9   obstcle      6647 non-null   object
#  10  meter        9994 non-null   category
#  11  Y            4250 non-null   float64
#  12  X            4281 non-null   float64
#  13  ID           10000 non-null  int64
#  14  flats        10000 non-null  int64
#  15  land_use     10000 non-null  category
#  16  capacity     10000 non-null  int64
#  17  diameter     10000 non-null  float64
# dtypes: category(3), float64(3), int64(11), object(1)
# memory usage: 1.3+ MB

# %%
df.head()
# Out:
#   district       doc  pre_date  cur_date  days  pre_read  cur_read  \
# 0        0  11292510    960418    970825    47      1564     16155
# 1        1  11705225    980921    961014    97     10395     12159
# 2        2  11147901    950426    980207   173     13502     13985
# 3        3  11157787    941010    990214   152      7385      3188
# 4        4  41119865    981125    960226    82     12472     12692
#
#    consumption     bill        obstcle     meter             Y              X  \
# 0          412   633996            NaN  13960219  4.079694e+06  270177.868594
# 1          371   568685     قرائت نشده  13950620           NaN            NaN
# 2          410   108353  از کار افتاده  13901224           NaN  272725.693345
# 3          433  1219749     قرائت نشده  13910212           NaN            NaN
# 4          486   136407     قرائت نشده  13971125           NaN  271984.104536
#
#          ID  flats land_use  capacity  diameter
# 0  46620700     42        0       100      0.75
# 1  43055800     17        0        70      0.75
# 2  36070600     13        0        66      0.75
# 3  42761200      9        0        60      0.75
# 4  12030900     42        0        17      0.75

# %%
na_features = [features for features in df.columns if df[features].isnull().sum()>1]
for feature in na_features:
    print(feature,'\t\t', np.round(df[feature].isnull().mean(),3), '%')
# Out:
# obstcle 		 0.335 %
# meter 		 0.001 %
# Y 		 0.575 %
# X 		 0.572 %

# %%
plt.scatter(df.bill, df.consumption)

# %%
plt.scatter(df.pre_date, df.pre_date)

# %%
plt.scatter(df.bill, df.pre_date)

# %%
df.capacity.value_counts()
# Out:
# 13     213
# 60     201
# 63     197
# 15     194
# 18     194
# 58     193
# 50     193
# 77     193
# 9      193
# 104    190
# 42     189
# 240    188
# 11     187
# 131    185
# 114    185
# 16     185
# 32     184
# 48     184
# 105    183
# 40     183
# 165    181
# 24     180
# 37     178
# 30     178
# 6      178
# 12     177
# 52     176
# 28     176
# 65     175
# 75     174
# 7      173
# 27     172
# 36     171
# 41     170
# 198    169
# 70     168
# 5      168
# 100    167
# 23     167
# 20     166
# 17     166
# 14     166
# 66     165
# 72     165
# 10     164
# 22     162
# 8      161
# 35     161
# 19     161
# 61     161
# 62     161
# 79     160
# 51     156
# 0      156
# 80     156
# 296    153
# 43     148
# Name: capacity, dtype: int64

# %%
temp_index = df[df['X'].isna()]
temp_index
# Out:
#      district       doc  pre_date  cur_date  days  pre_read  cur_read  \
# 1           1  11705225    980921    961014    97     10395     12159
# 3           3  11157787    941010    990214   152      7385      3188
# 5           5  11308718    950618    980908    20      6135     19288
# 6           6  11113402    990307    980205   436     12183     12067
# 7           3  11328638    960820    980925   233      3886       757
# ...       ...       ...       ...       ...   ...       ...       ...
# 9990        6  11678166    980631    950601   153     16007     17173
# 9994        4  11293800    951016    960513   213      1059      3509
# 9996        1  41174947    980211    950527   194      1943      2101
# 9997       10  11378414    970509    991105   136      6656     13796
# 9999        5  11375628    970206    980413   323     12845       344
#
#       consumption     bill        obstcle     meter             Y   X  \
# 1             371   568685     قرائت نشده  13950620           NaN NaN
# 3             433  1219749     قرائت نشده  13910212           NaN NaN
# 5             104  1612706            NaN  13970707  4.078123e+06 NaN
# 6             607  1056691     قرائت نشده  13950915  4.080191e+06 NaN
# 7             122  1261071  از کار افتاده  13900224           NaN NaN
# ...           ...      ...            ...       ...           ...  ..
# 9990           64   155966            NaN  13971206  4.080213e+06 NaN
# 9994           35   348058            NaN  13960115           NaN NaN
# 9996          912   738857  از کار افتاده  13910207  4.081315e+06 NaN
# 9997         1094   667080     قرائت نشده  13980222  5.443627e+01 NaN
# 9999          723   144327  از کار افتاده  13891208           NaN NaN
#
#             ID  flats land_use  capacity  diameter
# 1     43055800     17        0        70      0.75
# 3     42761200      9        0        60      0.75
# 5     24030500     16        0         6      0.75
# 6     42240900     11        0        30      0.75
# 7     42550800      3        0        37      0.75
# ...        ...    ...      ...       ...       ...
# 9990  51500300     15        0        16      0.75
# 9994  65176315      8        0       131      0.75
# 9996  26283200      5        0        35      0.75
# 9997  16450100      9        0        16      0.75
# 9999  46621600      5        0        30      0.75
#
# [5719 rows x 18 columns]

# %%
temp_index.index
# Out:
# Int64Index([   1,    3,    5,    6,    7,    9,   10,   12,   14,   15,
#             ...
#             9982, 9984, 9986, 9987, 9988, 9990, 9994, 9996, 9997, 9999],
#            dtype='int64', length=5719)

# %%
df_with_out_x_nan = df.drop(temp_index.index)
df_with_out_x_nan
# Out:
#      district       doc  pre_date  cur_date  days  pre_read  cur_read  \
# 0           0  11292510    960418    970825    47      1564     16155
# 2           2  11147901    950426    980207   173     13502     13985
# 4           4  41119865    981125    960226    82     12472     12692
# 8           5  11631137    981121    960903    57      9652      5353
# 11          5  41140023    960224    951026   125      5779      8912
# ...       ...       ...       ...       ...   ...       ...       ...
# 9991        5  11575457    981214    960425   138       565      4135
# 9992       13  11191951    980323    980128  1012      1308      9076
# 9993       13  11315935    980510    990829   180     19689      2201
# 9995        2  11550110    940828    971128   150       189     16256
# 9998       15  11444425    950630    960225    69      2515     10194
#
#       consumption     bill        obstcle     meter             Y  \
# 0             412   633996            NaN  13960219  4.079694e+06
# 2             410   108353  از کار افتاده  13901224           NaN
# 4             486   136407     قرائت نشده  13971125           NaN
# 8             432   166535            NaN  13950705  4.077075e+06
# 11            650  1494762            NaN  13910830  4.080220e+06
# ...           ...      ...            ...       ...           ...
# 9991          203   336739  از کار افتاده  13990630           NaN
# 9992          105  1004065  از کار افتاده  13950808           NaN
# 9993           69   368729  از کار افتاده  13991210           NaN
# 9995          158  1305197            NaN  13970531           NaN
# 9998          484   375932     قرائت نشده  13940722           NaN
#
#                   X        ID  flats land_use  capacity  diameter
# 0     270177.868594  46620700     42        0       100      0.75
# 2     272725.693345  36070600     13        0        66      0.75
# 4     271984.104536  12030900     42        0        17      0.75
# 8     270680.308017  22450500     20        0        13      0.75
# 11    272291.819571  27072500     12        0       114      0.75
# ...             ...       ...    ...      ...       ...       ...
# 9991  272997.684346  21541600     28        0        14      0.75
# 9992  273248.020265  26284200      4        0        23      0.75
# 9993  267614.567461  65231200      4        0       104      0.75
# 9995  272769.696846  42020400      3        0        28      0.75
# 9998  270826.247002  21413100      3        0        18      0.75
#
# [4281 rows x 18 columns]

# %%
x_train = df_with_out_x_nan[['district', 'doc', 'pre_date', 'cur_date', 'days', 'pre_read', 'cur_read'
                , 'consumption','bill', 'ID', 'flats', 'land_use', 'capacity', 'diameter']]
y_x = df_with_out_x_nan['X']

# %%
from sklearn.preprocessing import StandardScaler
std = StandardScaler()
x = std.fit_transform(x_train, y_x)

# %%
x[:5]
# Out:
# array([[-1.60756966, -0.50691404, -0.40185815, -0.05332666, -0.63056754,
#         -1.10204101,  1.14497083, -0.05362196, -0.27161207,  0.91042002,
#          3.03441543,  0.        ,  0.81619533,  0.        ],
#        [-1.17409845, -0.51682106, -1.0092167 ,  0.60625453, -0.22146602,
#          0.6904297 ,  0.80305016, -0.05932839, -0.81120392,  0.27983955,
#         -0.07383243,  0.        ,  0.19834057,  0.        ],
#        [-0.74062723,  1.53652912,  0.85680612, -0.79846641, -0.51692823,
#          0.53577693,  0.59931586,  0.15751612, -0.78240546, -1.15701559,
#          3.03441543,  0.        , -0.69209717,  0.        ],
#        [-0.52389163, -0.48371503,  0.85656298, -0.75087139, -0.59809917,
#          0.11235865, -0.55706929,  0.00344239, -0.75147796, -0.53423512,
#          0.67643429,  0.        , -0.76478596,  0.        ],
#        [-0.52389163,  1.53791012, -0.41365034, -1.44525248, -0.37731422,
#         -0.46916582,  0.00371212,  0.62544375,  0.61199586, -0.25797774,
#         -0.1810134 ,  0.        ,  1.07060611,  0.        ]])

# %%
x.shape
# Out:
# (4281, 14)

# %%
y_x[:5]
# Out:
# 0     270177.868594
# 2     272725.693345
# 4     271984.104536
# 8     270680.308017
# 11    272291.819571
# Name: X, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y_x, random_state=0, train_size=0.7)

# %%
print('size of x train : ', x_train.shape, '  size of y train : ', y_train.shape)
print('size of x test : ', x_test.shape, '  size of y test : ', y_test.shape)
# Out:
# size of x train :  (2996, 14)   size of y train :  (2996,)
# size of x test :  (1285, 14)   size of y test :  (1285,)

# %%
from sklearn.linear_model import LinearRegression
lr_model = LinearRegression()
lr_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
train_predict = lr_model.predict(x_train)

# %%
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error, r2_score

print('mean squared error of train :', mean_squared_error(train_predict, y_train))
print('mean_absolute_percentage_error of train :', mean_absolute_percentage_error(train_predict, y_train))
print('r2_score of train :', r2_score(train_predict, y_train))
# Out:
# mean squared error of train : 1546050314.732312
# mean_absolute_percentage_error of train : 0.04310025297366116
# r2_score of train : -268.599886951274
